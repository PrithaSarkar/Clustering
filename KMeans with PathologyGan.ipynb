# %% [markdown]
# Please uncomment the first cell to install Yellowbrick package (more about it in the report). !WARNING! C:/ drive must be given all permissions.

# %%
#pip install yellowbrick --user

# %% [markdown]
# Part of the script responsible for creating the plots showcasing the Silhouette Score has been pulled from : https://vitalflux.com/kmeans-silhouette-score-explained-with-python-example/#Perform_Comparative_Analysis_to_Determine_Best_value_of_K_using_Silhouette_Plot

# %%
import numpy as np
import pandas as pd
import os
import h5py
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context="notebook", palette="Spectral", style = 'whitegrid' ,font_scale = 1.5, color_codes=True)

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, v_measure_score
from yellowbrick.cluster import SilhouetteVisualizer

# %%
pathologygan = h5py.File('pge_dim_reduced_feature.h5', mode='r')
list(pathologygan.keys())
# Out:
# ['file_name', 'pca_feature', 'umap_feature']

# %%
dataset_fname=pathologygan['file_name']
dataset_pca=pathologygan['pca_feature']
dataset_umap=pathologygan['umap_feature']

# %%
ground_truth=dataset_fname[:]

# %%
range_n_clusters=np.arange(2,12)

# %%
X_pca=dataset_pca[:]

# %%
fig, ax = plt.subplots(5, 2, figsize=(18,15))
for n_clusters in range_n_clusters:
    kmeans_pca = KMeans(n_clusters = n_clusters, init = 'k-means++', random_state = 42)
    y=kmeans_pca.fit_predict(X_pca)
    score = silhouette_score(X_pca, y, metric='euclidean')
    print('Silhouette Score is {} when number of clusters are {}'.format(score, n_clusters))
    vms=v_measure_score(ground_truth, y)
    print('V Measure Score is {} when number of clusters are {}'.format(vms, n_clusters))
    q, mod = divmod(n_clusters, 2)
    visualizer = SilhouetteVisualizer(kmeans_pca, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(X_pca)
# Out:
# Silhouette Score is 0.3078377842903137 when number of clusters are 2
# V Measure Score is 0.1272716662795094 when number of clusters are 2
# Silhouette Score is 0.16621601581573486 when number of clusters are 3
# V Measure Score is 0.22158223988124734 when number of clusters are 3
# Silhouette Score is 0.1382039338350296 when number of clusters are 4
# V Measure Score is 0.2780569371830218 when number of clusters are 4
# Silhouette Score is 0.12949521839618683 when number of clusters are 5
# V Measure Score is 0.3113703055661178 when number of clusters are 5
# Silhouette Score is 0.13701753318309784 when number of clusters are 6
# V Measure Score is 0.3371798586527084 when number of clusters are 6
# Silhouette Score is 0.13732744753360748 when number of clusters are 7
# V Measure Score is 0.36476587441765423 when number of clusters are 7
# Silhouette Score is 0.13908691704273224 when number of clusters are 8
# V Measure Score is 0.3791111408768003 when number of clusters are 8
# Silhouette Score is 0.1417185515165329 when number of clusters are 9
# V Measure Score is 0.390881012305795 when number of clusters are 9
# Silhouette Score is 0.14476408064365387 when number of clusters are 10
# V Measure Score is 0.40432435742557365 when number of clusters are 10
# Silhouette Score is 0.1416027843952179 when number of clusters are 11
# V Measure Score is 0.4189951645893758 when number of clusters are 11

# %%
kmeans_pca = KMeans(n_clusters = 10, init = 'k-means++', random_state = 42)
y_kmeans_pca = kmeans_pca.fit_predict(X_pca)

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(X_pca[y_kmeans_pca == 0, 0], X_pca[y_kmeans_pca == 0, 1], color = '#93d3f7', label = 'Cluster 1',s=50)
sns.scatterplot(X_pca[y_kmeans_pca == 1, 0], X_pca[y_kmeans_pca == 1, 1], color = '#c793f7', label = 'Cluster 2',s=50)
sns.scatterplot(X_pca[y_kmeans_pca == 2, 0], X_pca[y_kmeans_pca == 2, 1], color = '#93f796', label = 'Cluster 3',s=50)
sns.scatterplot(X_pca[y_kmeans_pca == 3, 0], X_pca[y_kmeans_pca == 3, 1], color = '#f7c593', label = 'Cluster 4',s=50)
sns.scatterplot(X_pca[y_kmeans_pca == 4, 0], X_pca[y_kmeans_pca == 4, 1], color = '#f87581', label = 'Cluster 5',s=50)
sns.scatterplot(X_pca[y_kmeans_pca == 5, 0], X_pca[y_kmeans_pca == 5, 1], color = '#87f875', label = 'Cluster 6',s=50)
sns.scatterplot(X_pca[y_kmeans_pca == 6, 0], X_pca[y_kmeans_pca == 6, 1], color = '#f8b675', label = 'Cluster 7',s=50)
sns.scatterplot(X_pca[y_kmeans_pca == 7, 0], X_pca[y_kmeans_pca == 7, 1], color = '#9fb813', label = 'Cluster 8',s=50)
sns.scatterplot(X_pca[y_kmeans_pca == 8, 0], X_pca[y_kmeans_pca == 8, 1], color = '#13b846', label = 'Cluster 9',s=50)
sns.scatterplot(X_pca[y_kmeans_pca == 9, 0], X_pca[y_kmeans_pca == 9, 1], color = '#1342b8', label = 'Cluster 10',s=50)
sns.scatterplot(kmeans_pca.cluster_centers_[:, 0], kmeans_pca.cluster_centers_[:, 1], color = 'k', 
                label = 'Centroids',s=200,marker='*')
plt.grid(False)
plt.title('Clusters of Tissues')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X_umap = dataset_umap[:]

# %%
fig, ax = plt.subplots(5, 2, figsize=(18,15))
for n_clusters in range_n_clusters:
    kmeans_umap = KMeans(n_clusters = n_clusters, init = 'k-means++', random_state = 42)
    y=kmeans_umap.fit_predict(X_umap)
    score = silhouette_score(X_pca, y, metric='euclidean')
    print('Silhouette Score is {} when number of clusters are {}'.format(score, n_clusters))
    vms=v_measure_score(ground_truth, y)
    print('V Measure Score is {} when number of clusters are {}'.format(vms, n_clusters))
    q, mod = divmod(n_clusters, 2)
    visualizer = SilhouetteVisualizer(kmeans_umap, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(X_umap)
# Out:
# Silhouette Score is 0.02187868021428585 when number of clusters are 2
# V Measure Score is 0.06186705917596116 when number of clusters are 2
# Silhouette Score is 0.05788096785545349 when number of clusters are 3
# V Measure Score is 0.17332381127953378 when number of clusters are 3
# Silhouette Score is 0.09772177785634995 when number of clusters are 4
# V Measure Score is 0.23497904514684814 when number of clusters are 4
# Silhouette Score is 0.07280821353197098 when number of clusters are 5
# V Measure Score is 0.28328429653935483 when number of clusters are 5
# Silhouette Score is 0.08086182177066803 when number of clusters are 6
# V Measure Score is 0.2955010082584984 when number of clusters are 6
# Silhouette Score is 0.08177749067544937 when number of clusters are 7
# V Measure Score is 0.30833552247021295 when number of clusters are 7
# Silhouette Score is 0.08693328499794006 when number of clusters are 8
# V Measure Score is 0.35158669266509557 when number of clusters are 8
# Silhouette Score is 0.082491934299469 when number of clusters are 9
# V Measure Score is 0.38539589418361125 when number of clusters are 9
# Silhouette Score is 0.09305942803621292 when number of clusters are 10
# V Measure Score is 0.4052601675819087 when number of clusters are 10
# Silhouette Score is 0.1027723178267479 when number of clusters are 11
# V Measure Score is 0.4223959536859333 when number of clusters are 11

# %%
kmeans_umap = KMeans(n_clusters = 11, init = 'k-means++', random_state = 42)
y_kmeans_umap = kmeans_umap.fit_predict(X_umap)

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(X_umap[y_kmeans_umap == 0, 0], X_umap[y_kmeans_umap == 0, 1], color = '#93d3f7', label = 'Cluster 1',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 1, 0], X_umap[y_kmeans_umap == 1, 1], color = '#c793f7', label = 'Cluster 2',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 2, 0], X_umap[y_kmeans_umap == 2, 1], color = '#93f796', label = 'Cluster 3',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 3, 0], X_umap[y_kmeans_umap == 3, 1], color = '#f7c593', label = 'Cluster 4',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 4, 0], X_umap[y_kmeans_umap == 4, 1], color = '#f87581', label = 'Cluster 5',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 5, 0], X_umap[y_kmeans_umap == 5, 1], color = '#87f875', label = 'Cluster 6',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 6, 0], X_umap[y_kmeans_umap == 6, 1], color = '#f8b675', label = 'Cluster 7',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 7, 0], X_umap[y_kmeans_umap == 7, 1], color = '#9fb813', label = 'Cluster 8',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 8, 0], X_umap[y_kmeans_umap == 8, 1], color = '#13b846', label = 'Cluster 9',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 9, 0], X_umap[y_kmeans_umap == 9, 1], color = '#1342b8', label = 'Cluster 10',s=50)
sns.scatterplot(X_umap[y_kmeans_umap == 10, 0], X_umap[y_kmeans_umap == 10, 1], color = '#d09821', label = 'Cluster 11',s=50)
sns.scatterplot(kmeans_umap.cluster_centers_[:, 0], kmeans_umap.cluster_centers_[:, 1], color = 'k', 
                label = 'Centroids',s=200,marker='*')
plt.grid(False)
plt.title('Clusters of Tissues')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
